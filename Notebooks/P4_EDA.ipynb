# %% [markdown]
# # Metis Data Science Bootcamp
# ## San Francisco, Winter 2020
# ### Project 4: Election Reporting Sentiment Analysis

# %%
import sys
import re
import os.path
import requests
import time
import pandas as pd

from os import path

from pymongo import MongoClient

# %%
from sklearn.feature_extraction.text import CountVectorizer 
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import NMF
from sklearn.metrics.pairwise import cosine_similarity

# %%
db_client = MongoClient()
db_news = db_client['news_search']
db_news_col = db_news['search_result']

# %%
db_news_content = db_news['news_content']
cursor = db_news_content.find({}, {'_id':0, 'name': 1, 'text': 1, 'url' : 1, 'base_url' : 1, 'pub_date': 1})

# %%
char_count = 0;

for article in list(cursor) :
    for block in article['text'] :
        char_count += len(block)
        
print(char_count)
# Out:
# 14682206

# %%
cursor = db_news_content.find({}, {'_id':0, 'name': 1, 'text': 1, 'url' : 1, 'base_url' : 1, 'pub_date': 1})
print(len(list(cursor)))
# Out:
# 3088

# %%
import re
import string

alphanumeric = lambda x: re.sub('\w*\d\w*', ' ', x)
punc_lower = lambda x: re.sub('[%s]' % re.escape(string.punctuation+'\\'), ' ', x.lower())

# %%
db_news_content = db_news['news_content']

cursor = db_news_content.find({}, {'_id':0, 'name': 1, 'text': 1, 'url' : 1, 'base_url' : 1, 'pub_date': 1})
article_count = 0
total_words = 0

for article in list(cursor):
    word_list = []
    article_count += 1
    clean_text = ''
    clean_text = punc_lower(alphanumeric(article['text']))
    clean_text = re.sub('\w*\d\w*', ' ', clean_text)
    clean_text = article['text']
    word_list = clean_text.split()
    # print(article['name'], len(word_list))
    total_words += len(word_list)
    
print(article_count, total_words)
# Out:
# 3088 2322793

# %%
#db_news.news_search.update_many({}, { '$set' : { "scraped": 'y'}})

# %%
# First let's clean the text
cursor = db_news_content.find({}, {'_id':1, 'name': 1, 'text': 1, 'url' : 1, 'base_url' : 1, 'pub_date': 1})
db_news_sentences = db_news['sentences']
for article in list(cursor) :
    # make alphanumeric and lower case
    clean_text = punc_lower(alphanumeric(article['text']))
    
    # remove numbers
    clean_text = re.sub('\w*\d\w*', ' ', clean_text)
    
    # remove punctuation
    clean_text = re.sub('[%s]' % re.escape(string.punctuation), ' ', clean_text)
    clean_text = re.sub('\\xa0', ' ', clean_text)
    
    # word_list = clean_text.split()
    word_list = [ x for x in word_list if (len(x) >= 2) ]
    db_news_content.update_one({ '_id': article['_id']}, { '$set' : { 'clean_text' : clean_text }})
    db_news_content.update_one({ '_id': article['_id']}, { '$set' : { 'word_list' : word_list }})

# %%
cursor = db_news_content.find({}, {'_id':1, 'word_list' : 1 })
article = list(cursor)[0]
# Out:
# ['This',
#  'material',
#  'may',
#  'not',
#  'be',
#  'published,',
#  'broadcast,',
#  'rewritten,',
#  'or',
#  'redistributed.',
#  '©2020',
#  'FOX',
#  'News',
#  'Network,',
#  'LLC.',
#  'All',
#  'rights',
#  'reserved.',
#  'All',
#  'market',
#  'data',
#  'delayed',
#  '20',
#  'minutes.',
#  'Former',
#  'Obama',
#  'National',
#  'Finance',
#  'Committee',
#  'member',
#  'Don',
#  'Peebles',
#  'says',
#  '2020',
#  'hopeful',
#  'Sen.',
#  'Elizabeth',
#  "Warren's",
#  'aggressive',
#  'wealth',
#  'tax',
#  'plan',
#  'will',
#  'strangle',
#  'the',
#  'economy.Massachusetts',
#  'Sen.',
#  'Elizabeth',
#  'Warren',
#  'has',
#  'rallied',
#  'progressive',
#  'voters',
#  'in',
#  'what',
#  'has',
#  'proven',
#  'to',
#  'be',
#  'formidable',
#  'effort',
#  'to',
#  'become',
#  'the',
#  'second',
#  'consecutive',
#  'woman',
#  'to',
#  'secure',
#  'the',
#  'Democratic',
#  'nomination',
#  'for',
#  'president.',
#  'Following',
#  '30-year',
#  'career',
#  'as',
#  'law',
#  'professor,',
#  'she',
#  'unseated',
#  'moderate',
#  'Republican',
#  'Sen.',
#  'Scott',
#  'Brown',
#  'in',
#  '2012',
#  'before',
#  'winning',
#  'reelection',
#  'in',
#  '2018.',
#  'Warren',
#  'entered',
#  'the',
#  'race',
#  'for',
#  'president',
#  'in',
#  'February',
#  '2019.Here',
#  'is',
#  'where',
#  'Warren',
#  'stands',
#  'on',
#  'some',
#  'of',
#  'the',
#  'top',
#  'issues',
#  'voters',
#  'care',
#  'about',
#  'in',
#  'the',
#  '2020',
#  'campaign.Health',
#  'careOne',
#  'of',
#  'the',
#  'centerpieces',
#  'of',
#  "Warren's",
#  'campaign',
#  'for',
#  '"big,',
#  'structural',
#  'change"',
#  'is',
#  'complete',
#  'overhaul',
#  'of',
#  'the',
#  'American',
#  'health',
#  'care',
#  'system',
#  'under',
#  '"Medicare-for-all."Warren',
#  'says',
#  'she',
#  'would',
#  'use',
#  'the',
#  'first',
#  'couple',
#  'years',
#  'of',
#  'her',
#  'administration',
#  'to',
#  'help',
#  '"transition"',
#  'the',
#  'American',
#  'health',
#  'care',
#  'system',
#  'to',
#  '"Medicare-for-all"',
#  'by',
#  'creating',
#  'public',
#  'health',
#  'insurance',
#  'option',
#  'that',
#  'would',
#  'be',
#  'free',
#  'to',
#  'anyone',
#  'under',
#  '18',
#  'and',
#  'families',
#  'making',
#  'less',
#  'than',
#  'double',
#  'the',
#  'federal',
#  'poverty',
#  'line.FUNDING',
#  "'MEDICARE-FOR-ALL'",
#  'WITH',
#  'TAXES',
#  'ON',
#  'THE',
#  'RICH',
#  "'IMPOSSIBLE,'",
#  'STUDY',
#  'SAYSShe',
#  'further',
#  'promises',
#  'that',
#  '"no',
#  'later',
#  'than',
#  'my',
#  'third',
#  'year',
#  'in',
#  'office,',
#  'will',
#  'fight',
#  'to',
#  'pass',
#  'legislation',
#  'that',
#  'would',
#  'complete',
#  'the',
#  'transition',
#  'to',
#  'full',
#  'Medicare-for-all."Warren',
#  'has',
#  'said',
#  'she',
#  'can',
#  'fund',
#  'her',
#  'ambitious',
#  'health',
#  'care',
#  'plans',
#  '"without',
#  'raising',
#  'taxes',
#  'on',
#  'the',
#  'middle',
#  'class',
#  'by',
#  'one',
#  'penny."',
#  'This',
#  'has',
#  'been',
#  'disputed,',
#  'however,',
#  'by',
#  'the',
#  'nonpartisan',
#  'Committee',
#  'for',
#  'Responsible',
#  'Federal',
#  'Budget,',
#  'which',
#  'said',
#  'in',
#  'report',
#  'that',
#  'funding',
#  '"Medicare-for-all"',
#  'using',
#  'simply',
#  'taxes',
#  'on',
#  'the',
#  'rich',
#  'would',
#  'be',
#  '"impossible."Warren',
#  'says',
#  'that',
#  'percent',
#  'wealth',
#  'tax',
#  'on',
#  'families',
#  'worth',
#  'over',
#  '$1',
#  'billion',
#  'would',
#  'put',
#  'her',
#  '$52',
#  'trillion',
#  'plan',
#  'over',
#  'the',
#  'funding',
#  'finish',
#  'line,',
#  'though',
#  'Marc',
#  'Goldwein',
#  'of',
#  'the',
#  'CRFB',
#  'cast',
#  'doubt',
#  'that',
#  'the',
#  'tax',
#  'would',
#  'bring',
#  'in',
#  'the',
#  'amount',
#  'she',
#  'says',
#  'it',
#  'will."If',
#  'we',
#  'think',
#  'we’re',
#  'going',
#  'to',
#  'get',
#  '100',
#  'percent',
#  'of',
#  'our',
#  'expected',
#  'tax',
#  'base,',
#  'that’s',
#  'little',
#  'bit',
#  'of',
#  'fantasy',
#  'because',
#  'people',
#  'will',
#  'take',
#  'measures',
#  'to',
#  'avoid',
#  'the',
#  'tax,',
#  'including',
#  'some',
#  'that',
#  'aren’t',
#  'even',
#  'what',
#  'you’d',
#  'think',
#  'of',
#  'as',
#  'tax',
#  'avoidance,',
#  'just',
#  'like',
#  'spending',
#  'the',
#  'money',
#  'or',
#  'giving',
#  'it',
#  'to',
#  'charity,"',
#  'he',
#  'told',
#  'Fox',
#  'News.Warren',
#  'would',
#  'also',
#  'essentially',
#  'abolish',
#  'private',
#  'health',
#  'insurance',
#  'under',
#  'her',
#  '"Medicare-for-all"',
#  'plan,',
#  'as',
#  'would',
#  'her',
#  'progressive',
#  'opponent',
#  'Bernie',
#  'Sanders.',
#  'Other',
#  '2020',
#  'contenders,',
#  'including',
#  'Joe',
#  'Biden',
#  'and',
#  'Pete',
#  'Buttigieg,',
#  'would',
#  'allow',
#  'private',
#  'health',
#  'insurance',
#  'to',
#  'continue',
#  'to',
#  'exist.Climate',
#  'and',
#  'environmentWarren,',
#  'who',
#  'has',
#  'called',
#  'climate',
#  'change',
#  'an',
#  '"existential',
#  'threat,"',
#  'co-sponsored',
#  'Rep.',
#  'Alexandria',
#  "Ocasio-Cortez's",
#  'Green',
#  'New',
#  'Deal',
#  'resolution.',
#  'The',
#  'resolution',
#  'seeks',
#  'to',
#  'mobilize',
#  'the',
#  'federal',
#  'government',
#  'in',
#  'the',
#  'fight',
#  'against',
#  'climate',
#  'change',
#  'while',
#  'achieving',
#  'ambitious',
#  'social',
#  'justice',
#  'goals."The',
#  '#GreenNewDeal',
#  "isn't",
#  'just',
#  'an',
#  'agenda',
#  'for',
#  'reducing',
#  'carbon',
#  'emissions',
#  'and',
#  'defeating',
#  'the',
#  'climate',
#  'crisis',
#  "it's",
#  'an',
#  'opportunity',
#  'to',
#  'transform',
#  'our',
#  'economy',
#  'and',
#  'create',
#  'millions',
#  'of',
#  'good,',
#  'new',
#  'jobs.',
#  'American',
#  'ingenuity',
#  'can',
#  'rise',
#  'to',
#  'meet',
#  'this',
#  'challenge,"',
#  'Warren',
#  'tweeted',
#  'in',
#  "December.Warren's",
#  'climate',
#  'change',
#  'plan,',
#  'which',
#  'she',
#  'says',
#  'would',
#  'create',
#  'more',
#  'than',
#  '10',
#  'million',
#  'new',
#  'jobs,',
#  'particularly',
#  'through',
#  'green',
#  'manufacturing',
#  'plan',
#  'she',
#  'dubs',
#  'the',
#  '"Green',
#  'Apollo',
#  'Program,"',
#  'comes',
#  'with',
#  '$3',
#  'trillion',
#  'price',
#  'tag.',
#  'That',
#  'cost',
#  'is',
#  'almost',
#  'double',
#  'the',
#  'amount',
#  'the',
#  'more',
#  'moderate',
#  'Biden',
#  'plans',
#  'to',
#  'spend',
#  'fighting',
#  'climate',
#  'change,',
#  'but',
#  'just',
#  'fraction',
#  'of',
#  'the',
#  '$16',
#  'trillion',
#  'Sanders',
#  'says',
#  'he',
#  'would',
#  'spend',
#  'on',
#  'the',
#  'issue.Warren',
#  'sets',
#  '2050',
#  'as',
#  'the',
#  'goal',
#  'for',
#  'the',
#  'United',
#  'States',
#  'to',
#  'achieve',
#  'net-zero',
#  'carbon',
#  'emissions,',
#  'which',
#  'is',
#  'not',
#  'as',
#  'ambitious',
#  'as',
#  'some',
#  'other',
#  'Democrats',
#  'who',
#  'have',
#  'been',
#  'in',
#  'the',
#  'primary,',
#  'but',
#  'she',
#  'does',
#  'advocate',
#  'total',
#  'ban',
#  'on',
#  'fracking,',
#  'which',
#  'differentiates',
#  'her',
#  'from',
#  'Buttigieg',
#  'and',
#  'Biden.Economy',
#  'and',
#  'minimum',
#  'wageAs',
#  'income',
#  'inequality',
#  'has',
#  'become',
#  'big',
#  'issue',
#  'in',
#  'the',
#  'Democratic',
#  'primary,',
#  'Warren',
#  'has',
#  'taken',
#  'unique',
#  'approach',
#  'to',
#  'corporate',
#  'taxes.',
#  'While',
#  'some',
#  'candidates',
#  'advocate',
#  'raising',
#  'the',
#  'corporate',
#  'tax',
#  'rate',
#  'back',
#  'to',
#  '35',
#  'percent',
#  '--',
#  'the',
#  'level',
#  'it',
#  'was',
#  'before',
#  'President',
#  'Trump',
#  'signed',
#  'tax',
#  'reform',
#  'bill',
#  'in',
#  '2017',
#  '--',
#  'Warren',
#  'says',
#  'she',
#  'will',
#  'implement',
#  'at',
#  'percent',
#  'surtax',
#  'on',
#  'profits',
#  'for',
#  'extremely',
#  'large',
#  'companies.This',
#  'plan',
#  'leaves',
#  'the',
#  'Trump',
#  'tax',
#  'rates',
#  'in',
#  'place',
#  'for',
#  'most',
#  'companies',
#  'while',
#  'hitting',
#  'giant',
#  'corporations',
#  'which',
#  'Warren',
#  'says,',
#  '"make',
#  'huge',
#  'profits',
#  'but',
#  'pay',
#  'zero',
#  'federal',
#  'corporate',
#  'income',
#  'taxes',
#  'on',
#  'those',
#  'profits."Warren,',
#  'like',
#  'nearly',
#  'the',
#  'entire',
#  'Democratic',
#  'primary',
#  'field,',
#  'supports',
#  'raising',
#  'the',
#  'federal',
#  'minimum',
#  'wage',
#  'from',
#  '$7.25',
#  'to',
#  '$15.Additionally,',
#  "Warren's",
#  'proposal',
#  'for',
#  'wealth',
#  'tax',
#  'is',
#  'not',
#  'just',
#  'for',
#  'funding',
#  '"Medicare-for-all."',
#  'While',
#  'she',
#  'hopes',
#  'to',
#  'hit',
#  'families',
#  'worth',
#  'over',
#  '$1',
#  'billion',
#  'for',
#  'percent',
#  'of',
#  'their',
#  'wealth',
#  'each',
#  'year',
#  'to',
#  'fund',
#  'her',
#  'health',
#  'care',
#  'plan,',
#  'she',
#  'also',
#  'says',
#  'she',
#  'will',
#  'fix',
#  'percent',
#  'levy',
#  'on',
#  'all',
#  'families',
#  'worth',
#  'over',
#  '$50',
#  'million.With',
#  'the',
#  'nearly',
#  '$3',
#  'trillion',
#  'she',
#  'plans',
#  'to',
#  'bring',
#  'in',
#  'through',
#  'that',
#  'wealth',
#  'tax,',
#  'Warren',
#  'says',
#  'she',
#  'will',
#  'fund',
#  'no',
#  'less',
#  'than',
#  'eight',
#  'separate',
#  "initiatives:WARREN'S",
#  "'FANTASY'",
#  'WEALTH',
#  'TAX:',
#  "HERE'S",
#  'ALL',
#  'THE',
#  'PROGRAMS',
#  '2020',
#  'DEM',
#  'CLAIMS',
#  'TO',
#  'COVER',
#  'WTH',
#  'FUNDING',
#  'TRICKMost',
#  'of',
#  'the',
#  'top',
#  'candidates',
#  'remaining',
#  'in',
#  'the',
#  'race,',
#  'excluding',
#  'Biden,',
#  'have',
#  'voiced',
#  'support',
#  'for',
#  'some',
#  'form',
#  'of',
#  'wealth',
#  'tax.',
#  'There',
#  'are',
#  'questions',
#  'not',
#  'just',
#  'about',
#  'the',
#  'effectiveness',
#  'of',
#  'wealth',
#  'tax,',
#  'however,',
#  'but',
#  'also',
#  'its',
#  'constitutionality."The',
#  'Constitution',
#  'does',
#  'not',
#  'specifically',
#  'empower',
#  'Congress',
#  'to',
#  'adopt',
#  'wealth',
#  'or',
#  'asset',
#  'tax',
#  '(as',
#  'with',
#  'the',
#  'Sixteenth',
#  'Amendment),',
#  'an',
#  'asset',
#  'tax',
#  'cannot',
#  'be',
#  "'equally",
#  "apportioned'",
#  '(by',
#  'definition,',
#  'it',
#  'takes',
#  'only',
#  'from',
#  'the',
#  'better',
#  'off),',
#  'and',
#  'possessing',
#  'wealth',
#  'or',
#  'assets',
#  'is',
#  'not,',
#  'by',
#  'definition,',
#  "'transaction'",
#  '(any',
#  'more',
#  'than',
#  'owning',
#  'home',
#  'is),"',
#  'Heritage',
#  'Foundation',
#  'Research',
#  'Associate',
#  'Joel',
#  'Griffith',
#  'wrote',
#  'for',
#  'Fox',
#  'News',
#  'last',
#  'year.',
#  '"In',
#  'fact,',
#  'seizing',
#  'this',
#  'private',
#  'property',
#  'without',
#  'just',
#  'compensation',
#  'would',
#  'clearly',
#  'violate',
#  'the',
#  'Fifth',
#  'Amendment',
#  'Takings',
#  'Clause."ImmigrationWarren,',
#  'like',
#  'other',
#  '2020',
#  'Democrats,',
#  'has',
#  'lambasted',
#  "Trump's",
#  'immigration',
#  'policies',
#  'and',
#  'his',
#  "administration's",
#  'treatment',
#  'of',
#  'immigrants."He’s',
#  'advanced',
#  'policy',
#  'of',
#  'cruelty',
#  'and',
#  'division',
#  'that',
#  'demonizes',
#  'immigrants,"',
#  'Warren',
#  'writes',
#  'of',
#  'the',
#  'president',
#  'on',
#  'her',
#  'website.',
#  '"He’s',
#  'axed',
#  'programs',
#  'that',
#  'protect',
#  'young',
#  'Dreamers',
#  'and',
#  'asylum',
#  'seekers',
#  'fleeing',
#  'violence',
#  'and',
#  'upheaval.',
#  'He’s',
#  'championed',
#  'dramatic',
#  'cuts',
#  'to',
#  'legal',
#  'immigration,',
#  'and',
#  'imposed',
#  'bigoted',
#  'ban',
#  'on',
#  'travelers',
#  'from',
#  'Muslim-majority',
#  'countries."While',
#  'some',
#  'Democrats',
#  'in',
#  'the',
#  '2020',
#  'field',
#  'have',
#  'said',
#  'they',
#  'would',
#  'be',
#  'open',
#  'to',
#  'some',
#  'physical',
#  'barrier',
#  'on',
#  'the',
#  'southern',
#  'border',
#  'in',
#  'some',
#  'cases,',
#  'Warren',
#  'has',
#  'professed',
#  'that',
#  'she',
#  'is',
#  'against',
#  'any',
#  'type',
#  'of',
#  'wall',
#  'or',
#  'fence.',
#  'She',
#  'has',
#  'also',
#  'said',
#  'she',
#  ...]

# %% [markdown]
# ## Named Entitity Identification

# %%
import spacy
from spacy import displacy
from pprint import pprint
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
from spacy.lang.en import English
nlp = English()
# Create a Tokenizer with the default settings for English
# including punctuation rules and exceptions
sentencizer = nlp.create_pipe("sentencizer")
nlp.add_pipe(sentencizer)

tokenizer = nlp.Defaults.create_tokenizer(nlp)from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Create a SentimentIntensityAnalyzer object. 
sid_obj = SentimentIntensityAnalyzer()

        
cursor = db_news_sentences.find({}, {'_id':1, 'text': 1, 'parent_id':1})
sentence = list(cursor)[0]

sentiment_dict = sid_obj.polarity_scores(sentence['text'])
sentiment_dict

# %%
# First let's clean the text
cursor = db_news_content.find({}, {'_id':1, 'name': 1, 'text': 1, 'url' : 1, 'base_url' : 1, 'pub_date': 1})
db_news_sentences = db_news['sentences']
for article in list(cursor) :
    # make alphanumeric and lower case
    # clean_text = punc_lower(alphanumeric(article['text']))
    
    # remove numbers
    #clean_text = re.sub('\w*\d\w*', ' ', clean_text)
    clean_text = re.sub('\\xa0', ' ', article['text'])
    
    doc = nlp(clean_text)
    
    for sent in doc.sents:
        sentiment_dict = sid_obj.polarity_scores(sentence['text'])
        db_news_sentences.insert_one({'parent_id': article['_id'], 'text' : sent.text, 'sentiment': sentiment_dict})

# %%
score_list = []        
cursor = db_news_sentences.find({}, {'_id':1, 'text': 1, 'parent_id':1, 'sentiment':1})
for sentence in list(cursor) :
    score_list.append(sentence['sentiment']['compound'])
    
db_news_sentences.count_documents({})
# Out:
# 81682

# %%
import matplotlib.pyplot as plt

plt.hist(score_list)
# Out:
# (array([ 216.,   43.,   31.,   28.,   18.,  138.,   49.,   69.,   96.,
#         1517.]),
#  array([-0.9999 , -0.79992, -0.59994, -0.39996, -0.19998,  0.     ,
#          0.19998,  0.39996,  0.59994,  0.79992,  0.9999 ]),
#  <a list of 10 Patch objects>)

# %%
max(score_list)
# Out:
# 0.0

# %%
cursor = db_news_content.find({}, {'_id':1, 'name': 1, 'text': 1, 'url' : 1, 'base_url' : 1, 'pub_date': 1})
score_list = []
for article in list(cursor) :
    score_list.append(sid_obj.polarity_scores(article['text'])['compound'])

# %%
max(score_list)
# Out:
# 0.9999

# %%
# db_news.drop_collection('sentences')
# Out:
# {'nIndexesWas': 1, 'ns': 'news_search.sentences', 'ok': 1.0}

# %%
cursor = db_news_content.find({}, {'_id':1, 'clean_text' : 1 })
article = list(cursor)[0]

text = tokenizer(article['clean_text'])
# Tag the parts of speech
doc = nlp(text.text)

# tokenize the text
word_list = [token.text for token in doc if not token.is_stop]
word_list = [token for token in word_list if token.isalpha() and (len(token) >= 2)]
word_list
# Out:
# ['washington',
#  'bernie',
#  'sanders',
#  'said',
#  'tuesday',
#  'night',
#  'planning',
#  'release',
#  'additional',
#  'medical',
#  'records',
#  'sanders',
#  'suffered',
#  'heart',
#  'attack',
#  'october',
#  'campaign',
#  'event',
#  'blockage',
#  'artery',
#  'stents',
#  'inserted',
#  'campaign',
#  'said',
#  'time',
#  'speaking',
#  'cnn',
#  'town',
#  'hall',
#  'las',
#  'vegas',
#  'sanders',
#  'asked',
#  'clarify',
#  'presidential',
#  'campaign',
#  'releasing',
#  'medical',
#  'records',
#  'previously',
#  'stated',
#  'sanders',
#  'democractic',
#  'candidate',
#  'debate',
#  'wedneday',
#  'night',
#  'warren',
#  'rips',
#  'bloomberg',
#  'egomaniac',
#  'billionaire',
#  'dems',
#  'prepare',
#  'new',
#  'rival',
#  'debate',
#  'stageat',
#  'time',
#  'said',
#  'people',
#  'right',
#  'know',
#  'health',
#  'senator',
#  'somebody',
#  'running',
#  'president',
#  'united',
#  'states',
#  'disclosure',
#  'tuesday',
#  'said',
#  'released',
#  'documentation',
#  'candidate',
#  'reiterated',
#  'letters',
#  'cardiologists',
#  'doctors',
#  'said',
#  'good',
#  'health',
#  'think',
#  'released',
#  'detailed',
#  'medical',
#  'report',
#  'comfortable',
#  'sanders',
#  'said',
#  'asked',
#  'clarify',
#  'releasing',
#  'medical',
#  'records',
#  'sanders',
#  'concluded',
#  'think',
#  'sanders',
#  'oldest',
#  'president',
#  'history',
#  'elected',
#  'question',
#  'came',
#  'nbc',
#  'chuck',
#  'todd',
#  'asked',
#  'senator',
#  'meet',
#  'press',
#  'releasing',
#  'information',
#  'host',
#  'pushing',
#  'candidates',
#  'heart',
#  'attack']

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Create a SentimentIntensityAnalyzer object. 
sid_obj = SentimentIntensityAnalyzer()

        
cursor = db_news_sentences.find({}, {'_id':1, 'text': 1, 'parent_id':1})
sentence = list(cursor)[0]

sentiment_dict = sid_obj.polarity_scores(sentence['text'])
sentiment_dict
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# []

# %%
js = doc.to_json()
pprint(js)
# Out:
# {'ents': [{'end': 10, 'label': 'GPE', 'start': 0},
#           {'end': 27, 'label': 'PERSON', 'start': 13},
#           {'end': 40, 'label': 'DATE', 'start': 33},
#           {'end': 46, 'label': 'TIME', 'start': 41},
#           {'end': 125, 'label': 'DATE', 'start': 123},
#           {'end': 161, 'label': 'DATE', 'start': 154},
#           {'end': 211, 'label': 'CARDINAL', 'start': 208},
#           {'end': 226, 'label': 'CARDINAL', 'start': 223},
#           {'end': 298, 'label': 'ORG', 'start': 295},
#           {'end': 323, 'label': 'GPE', 'start': 314},
#           {'end': 332, 'label': 'ORG', 'start': 325},
#           {'end': 510, 'label': 'LOC', 'start': 499},
#           {'end': 542, 'label': 'TIME', 'start': 528},
#           {'end': 555, 'label': 'PERSON', 'start': 549},
#           {'end': 570, 'label': 'PERSON', 'start': 561},
#           {'end': 605, 'label': 'NORP', 'start': 601},
#           {'end': 645, 'label': 'CARDINAL', 'start': 638},
#           {'end': 789, 'label': 'GPE', 'start': 772},
#           {'end': 826, 'label': 'DATE', 'start': 819},
#           {'end': 1102, 'label': 'ORG', 'start': 1095},
#           {'end': 1185, 'label': 'ORG', 'start': 1178},
#           {'end': 1312, 'label': 'ORG', 'start': 1309},
#           {'end': 1325, 'label': 'PERSON', 'start': 1315},
#           {'end': 1368, 'label': 'WORK_OF_ART', 'start': 1354}],
#  'sents': [{'end': 12, 'start': 0},
#            {'end': 114, 'start': 13},
#            {'end': 187, 'start': 114},
#            {'end': 279, 'start': 187},
#            {'end': 468, 'start': 279},
#            {'end': 544, 'start': 469},
#            {'end': 809, 'start': 544},
#            {'end': 817, 'start': 809},
#            {'end': 1000, 'start': 817},
#            {'end': 1108, 'start': 1000},
#            {'end': 1285, 'start': 1108},
#            {'end': 1483, 'start': 1285}],
#  'text': 'WASHINGTON\xa0– Bernie Sanders said Tuesday night that he is\xa0not '
#          'planning to release any additional medical records.\xa0Sanders, 78, '
#          'suffered a heart attack\xa0in October during a campaign event.\xa0He '
#          'had a blockage in one artery and two stents were inserted, his '
#          "campaign said at the time.Speaking during CNN's town hall in Las "
#          'Vegas, Sanders was asked to clarify whether his presidential '
#          'campaign would be releasing full medical records, which he '
#          'previously\xa0stated\xa0he would do. Sanders will take part in the '
#          'Democractic candidate debate Wedneday night.\xa0More:Warren rips '
#          "Bloomberg as 'egomaniac billionaire' as Dems prepare for new rival "
#          'on debate stageAt the time, he said,\xa0"The people do have a right '
#          "to know about the health of a senator, somebody who's running for "
#          'president of the United States -- full disclosure."However, Tuesday '
#          'he said:\xa0“We have released quite as much documentation as any '
#          'other candidate has" and\xa0reiterated that letters from '
#          'cardiologists and doctors have said he is in good health.“I think we '
#          'have released a detailed medical report and I’m comfortable on what '
#          'we have done," Sanders said.When asked to clarify whether he\'d be '
#          'releasing full medical records, Sanders concluded,\xa0“I don’t think '
#          'we will, no.”Sanders would be the oldest president in history if '
#          "elected.The question came after NBC's Chuck Todd first\xa0asked the "
#          'Senator on "Meet the Press" if he\'d be releasing any more '
#          'information, with the host pushing that, "No other candidates had a '
#          'heart attack."\xa0',
#  'tokens': [{'dep': 'ROOT',
#              'end': 10,
#              'head': 0,
#              'id': 0,
#              'pos': 'PROPN',
#              'start': 0,
#              'tag': 'NNP'},
#             {'dep': '',
#              'end': 11,
#              'head': 0,
#              'id': 1,
#              'pos': 'SPACE',
#              'start': 10,
#              'tag': '_SP'},
#             {'dep': 'punct',
#              'end': 12,
#              'head': 0,
#              'id': 2,
#              'pos': 'PUNCT',
#              'start': 11,
#              'tag': ':'},
#             {'dep': 'compound',
#              'end': 19,
#              'head': 4,
#              'id': 3,
#              'pos': 'PROPN',
#              'start': 13,
#              'tag': 'NNP'},
#             {'dep': 'nsubj',
#              'end': 27,
#              'head': 5,
#              'id': 4,
#              'pos': 'PROPN',
#              'start': 20,
#              'tag': 'NNP'},
#             {'dep': 'ROOT',
#              'end': 32,
#              'head': 5,
#              'id': 5,
#              'pos': 'VERB',
#              'start': 28,
#              'tag': 'VBD'},
#             {'dep': 'compound',
#              'end': 40,
#              'head': 7,
#              'id': 6,
#              'pos': 'PROPN',
#              'start': 33,
#              'tag': 'NNP'},
#             {'dep': 'npadvmod',
#              'end': 46,
#              'head': 5,
#              'id': 7,
#              'pos': 'NOUN',
#              'start': 41,
#              'tag': 'NN'},
#             {'dep': 'mark',
#              'end': 51,
#              'head': 10,
#              'id': 8,
#              'pos': 'SCONJ',
#              'start': 47,
#              'tag': 'IN'},
#             {'dep': 'nsubj',
#              'end': 54,
#              'head': 10,
#              'id': 9,
#              'pos': 'PRON',
#              'start': 52,
#              'tag': 'PRP'},
#             {'dep': 'aux',
#              'end': 57,
#              'head': 13,
#              'id': 10,
#              'pos': 'AUX',
#              'start': 55,
#              'tag': 'VBZ'},
#             {'dep': '',
#              'end': 58,
#              'head': 10,
#              'id': 11,
#              'pos': 'SPACE',
#              'start': 57,
#              'tag': '_SP'},
#             {'dep': 'neg',
#              'end': 61,
#              'head': 13,
#              'id': 12,
#              'pos': 'PART',
#              'start': 58,
#              'tag': 'RB'},
#             {'dep': 'ccomp',
#              'end': 70,
#              'head': 5,
#              'id': 13,
#              'pos': 'VERB',
#              'start': 62,
#              'tag': 'VBG'},
#             {'dep': 'aux',
#              'end': 73,
#              'head': 15,
#              'id': 14,
#              'pos': 'PART',
#              'start': 71,
#              'tag': 'TO'},
#             {'dep': 'xcomp',
#              'end': 81,
#              'head': 13,
#              'id': 15,
#              'pos': 'VERB',
#              'start': 74,
#              'tag': 'VB'},
#             {'dep': 'det',
#              'end': 85,
#              'head': 19,
#              'id': 16,
#              'pos': 'DET',
#              'start': 82,
#              'tag': 'DT'},
#             {'dep': 'amod',
#              'end': 96,
#              'head': 19,
#              'id': 17,
#              'pos': 'ADJ',
#              'start': 86,
#              'tag': 'JJ'},
#             {'dep': 'amod',
#              'end': 104,
#              'head': 19,
#              'id': 18,
#              'pos': 'ADJ',
#              'start': 97,
#              'tag': 'JJ'},
#             {'dep': 'dobj',
#              'end': 112,
#              'head': 15,
#              'id': 19,
#              'pos': 'NOUN',
#              'start': 105,
#              'tag': 'NNS'},
#             {'dep': 'punct',
#              'end': 113,
#              'head': 5,
#              'id': 20,
#              'pos': 'PUNCT',
#              'start': 112,
#              'tag': '.'},
#             {'dep': '',
#              'end': 114,
#              'head': 20,
#              'id': 21,
#              'pos': 'SPACE',
#              'start': 113,
#              'tag': '_SP'},
#             {'dep': 'nsubj',
#              'end': 121,
#              'head': 26,
#              'id': 22,
#              'pos': 'PROPN',
#              'start': 114,
#              'tag': 'NNP'},
#             {'dep': 'punct',
#              'end': 122,
#              'head': 22,
#              'id': 23,
#              'pos': 'PUNCT',
#              'start': 121,
#              'tag': ','},
#             {'dep': 'appos',
#              'end': 125,
#              'head': 22,
#              'id': 24,
#              'pos': 'NUM',
#              'start': 123,
#              'tag': 'CD'},
#             {'dep': 'punct',
#              'end': 126,
#              'head': 22,
#              'id': 25,
#              'pos': 'PUNCT',
#              'start': 125,
#              'tag': ','},
#             {'dep': 'ROOT',
#              'end': 135,
#              'head': 26,
#              'id': 26,
#              'pos': 'VERB',
#              'start': 127,
#              'tag': 'VBD'},
#             {'dep': 'det',
#              'end': 137,
#              'head': 29,
#              'id': 27,
#              'pos': 'DET',
#              'start': 136,
#              'tag': 'DT'},
#             {'dep': 'compound',
#              'end': 143,
#              'head': 29,
#              'id': 28,
#              'pos': 'NOUN',
#              'start': 138,
#              'tag': 'NN'},
#             {'dep': 'dobj',
#              'end': 150,
#              'head': 26,
#              'id': 29,
#              'pos': 'NOUN',
#              'start': 144,
#              'tag': 'NN'},
#             {'dep': '',
#              'end': 151,
#              'head': 29,
#              'id': 30,
#              'pos': 'SPACE',
#              'start': 150,
#              'tag': '_SP'},
#             {'dep': 'prep',
#              'end': 153,
#              'head': 26,
#              'id': 31,
#              'pos': 'ADP',
#              'start': 151,
#              'tag': 'IN'},
#             {'dep': 'pobj',
#              'end': 161,
#              'head': 31,
#              'id': 32,
#              'pos': 'PROPN',
#              'start': 154,
#              'tag': 'NNP'},
#             {'dep': 'prep',
#              'end': 168,
#              'head': 26,
#              'id': 33,
#              'pos': 'ADP',
#              'start': 162,
#              'tag': 'IN'},
#             {'dep': 'det',
#              'end': 170,
#              'head': 36,
#              'id': 34,
#              'pos': 'DET',
#              'start': 169,
#              'tag': 'DT'},
#             {'dep': 'compound',
#              'end': 179,
#              'head': 36,
#              'id': 35,
#              'pos': 'NOUN',
#              'start': 171,
#              'tag': 'NN'},
#             {'dep': 'pobj',
#              'end': 185,
#              'head': 33,
#              'id': 36,
#              'pos': 'NOUN',
#              'start': 180,
#              'tag': 'NN'},
#             {'dep': 'punct',
#              'end': 186,
#              'head': 26,
#              'id': 37,
#              'pos': 'PUNCT',
#              'start': 185,
#              'tag': '.'},
#             {'dep': '',
#              'end': 187,
#              'head': 37,
#              'id': 38,
#              'pos': 'SPACE',
#              'start': 186,
#              'tag': '_SP'},
#             {'dep': 'nsubj',
#              'end': 189,
#              'head': 40,
#              'id': 39,
#              'pos': 'PRON',
#              'start': 187,
#              'tag': 'PRP'},
#             {'dep': 'ccomp',
#              'end': 193,
#              'head': 54,
#              'id': 40,
#              'pos': 'AUX',
#              'start': 190,
#              'tag': 'VBD'},
#             {'dep': 'det',
#              'end': 195,
#              'head': 42,
#              'id': 41,
#              'pos': 'DET',
#              'start': 194,
#              'tag': 'DT'},
#             {'dep': 'dobj',
#              'end': 204,
#              'head': 40,
#              'id': 42,
#              'pos': 'NOUN',
#              'start': 196,
#              'tag': 'NN'},
#             {'dep': 'prep',
#              'end': 207,
#              'head': 40,
#              'id': 43,
#              'pos': 'ADP',
#              'start': 205,
#              'tag': 'IN'},
#             {'dep': 'nummod',
#              'end': 211,
#              'head': 45,
#              'id': 44,
#              'pos': 'NUM',
#              'start': 208,
#              'tag': 'CD'},
#             {'dep': 'pobj',
#              'end': 218,
#              'head': 43,
#              'id': 45,
#              'pos': 'NOUN',
#              'start': 212,
#              'tag': 'NN'},
#             {'dep': 'cc',
#              'end': 222,
#              'head': 40,
#              'id': 46,
#              'pos': 'CCONJ',
#              'start': 219,
#              'tag': 'CC'},
#             {'dep': 'nummod',
#              'end': 226,
#              'head': 48,
#              'id': 47,
#              'pos': 'NUM',
#              'start': 223,
#              'tag': 'CD'},
#             {'dep': 'nsubjpass',
#              'end': 233,
#              'head': 50,
#              'id': 48,
#              'pos': 'NOUN',
#              'start': 227,
#              'tag': 'NNS'},
#             {'dep': 'auxpass',
#              'end': 238,
#              'head': 50,
#              'id': 49,
#              'pos': 'AUX',
#              'start': 234,
#              'tag': 'VBD'},
#             {'dep': 'conj',
#              'end': 247,
#              'head': 40,
#              'id': 50,
#              'pos': 'VERB',
#              'start': 239,
#              'tag': 'VBN'},
#             {'dep': 'punct',
#              'end': 248,
#              'head': 54,
#              'id': 51,
#              'pos': 'PUNCT',
#              'start': 247,
#              'tag': ','},
#             {'dep': 'poss',
#              'end': 252,
#              'head': 53,
#              'id': 52,
#              'pos': 'DET',
#              'start': 249,
#              'tag': 'PRP$'},
#             {'dep': 'nsubj',
#              'end': 261,
#              'head': 54,
#              'id': 53,
#              'pos': 'NOUN',
#              'start': 253,
#              'tag': 'NN'},
#             {'dep': 'ROOT',
#              'end': 266,
#              'head': 54,
#              'id': 54,
#              'pos': 'VERB',
#              'start': 262,
#              'tag': 'VBD'},
#             {'dep': 'prep',
#              'end': 269,
#              'head': 54,
#              'id': 55,
#              'pos': 'ADP',
#              'start': 267,
#              'tag': 'IN'},
#             {'dep': 'det',
#              'end': 273,
#              'head': 57,
#              'id': 56,
#              'pos': 'DET',
#              'start': 270,
#              'tag': 'DT'},
#             {'dep': 'pobj',
#              'end': 278,
#              'head': 55,
#              'id': 57,
#              'pos': 'NOUN',
#              'start': 274,
#              'tag': 'NN'},
#             {'dep': 'punct',
#              'end': 279,
#              'head': 54,
#              'id': 58,
#              'pos': 'PUNCT',
#              'start': 278,
#              'tag': '.'},
#             {'dep': 'advcl',
#              'end': 287,
#              'head': 71,
#              'id': 59,
#              'pos': 'VERB',
#              'start': 279,
#              'tag': 'VBG'},
#             {'dep': 'prep',
#              'end': 294,
#              'head': 59,
#              'id': 60,
#              'pos': 'ADP',
#              'start': 288,
#              'tag': 'IN'},
#             {'dep': 'poss',
#              'end': 298,
#              'head': 64,
#              'id': 61,
#              'pos': 'PROPN',
#              'start': 295,
#              'tag': 'NNP'},
#             {'dep': 'case',
#              'end': 300,
#              'head': 61,
#              'id': 62,
#              'pos': 'PART',
#              'start': 298,
#              'tag': 'POS'},
#             {'dep': 'compound',
#              'end': 305,
#              'head': 64,
#              'id': 63,
#              'pos': 'NOUN',
#              'start': 301,
#              'tag': 'NN'},
#             {'dep': 'pobj',
#              'end': 310,
#              'head': 60,
#              'id': 64,
#              'pos': 'NOUN',
#              'start': 306,
#              'tag': 'NN'},
#             {'dep': 'prep',
#              'end': 313,
#              'head': 64,
#              'id': 65,
#              'pos': 'ADP',
#              'start': 311,
#              'tag': 'IN'},
#             {'dep': 'compound',
#              'end': 317,
#              'head': 67,
#              'id': 66,
#              'pos': 'PROPN',
#              'start': 314,
#              'tag': 'NNP'},
#             {'dep': 'pobj',
#              'end': 323,
#              'head': 65,
#              'id': 67,
#              'pos': 'PROPN',
#              'start': 318,
#              'tag': 'NNP'},
#             {'dep': 'punct',
#              'end': 324,
#              'head': 71,
#              'id': 68,
#              'pos': 'PUNCT',
#              'start': 323,
#              'tag': ','},
#             {'dep': 'nsubjpass',
#              'end': 332,
#              'head': 71,
#              'id': 69,
#              'pos': 'PROPN',
#              'start': 325,
#              'tag': 'NNP'},
#             {'dep': 'auxpass',
#              'end': 336,
#              'head': 71,
#              'id': 70,
#              'pos': 'AUX',
#              'start': 333,
#              'tag': 'VBD'},
#             {'dep': 'ROOT',
#              'end': 342,
#              'head': 71,
#              'id': 71,
#              'pos': 'VERB',
#              'start': 337,
#              'tag': 'VBN'},
#             {'dep': 'aux',
#              'end': 345,
#              'head': 73,
#              'id': 72,
#              'pos': 'PART',
#              'start': 343,
#              'tag': 'TO'},
#             {'dep': 'xcomp',
#              'end': 353,
#              'head': 71,
#              'id': 73,
#              'pos': 'VERB',
#              'start': 346,
#              'tag': 'VB'},
#             {'dep': 'mark',
#              'end': 361,
#              'head': 80,
#              'id': 74,
#              'pos': 'SCONJ',
#              'start': 354,
#              'tag': 'IN'},
#             {'dep': 'poss',
#              'end': 365,
#              'head': 77,
#              'id': 75,
#              'pos': 'DET',
#              'start': 362,
#              'tag': 'PRP$'},
#             {'dep': 'amod',
#              'end': 378,
#              'head': 77,
#              'id': 76,
#              'pos': 'ADJ',
#              'start': 366,
#              'tag': 'JJ'},
#             {'dep': 'nsubj',
#              'end': 387,
#              'head': 80,
#              'id': 77,
#              'pos': 'NOUN',
#              'start': 379,
#              'tag': 'NN'},
#             {'dep': 'aux',
#              'end': 393,
#              'head': 80,
#              'id': 78,
#              'pos': 'VERB',
#              'start': 388,
#              'tag': 'MD'},
#             {'dep': 'aux',
#              'end': 396,
#              'head': 80,
#              'id': 79,
#              'pos': 'AUX',
#              'start': 394,
#              'tag': 'VB'},
#             {'dep': 'ccomp',
#              'end': 406,
#              'head': 73,
#              'id': 80,
#              'pos': 'VERB',
#              'start': 397,
#              'tag': 'VBG'},
#             {'dep': 'amod',
#              'end': 411,
#              'head': 83,
#              'id': 81,
#              'pos': 'ADJ',
#              'start': 407,
#              'tag': 'JJ'},
#             {'dep': 'amod',
#              'end': 419,
#              'head': 83,
#              'id': 82,
#              'pos': 'ADJ',
#              'start': 412,
#              'tag': 'JJ'},
#             {'dep': 'dobj',
#              'end': 427,
#              'head': 80,
#              'id': 83,
#              'pos': 'NOUN',
#              'start': 420,
#              'tag': 'NNS'},
#             {'dep': 'punct',
#              'end': 428,
#              'head': 83,
#              'id': 84,
#              'pos': 'PUNCT',
#              'start': 427,
#              'tag': ','},
#             {'dep': 'dobj',
#              'end': 434,
#              'head': 89,
#              'id': 85,
#              'pos': 'DET',
#              'start': 429,
#              'tag': 'WDT'},
#             {'dep': 'nsubj',
#              'end': 437,
#              'head': 89,
#              'id': 86,
#              'pos': 'PRON',
#              'start': 435,
#              'tag': 'PRP'},
#             {'dep': 'advmod',
#              'end': 448,
#              'head': 89,
#              'id': 87,
#              'pos': 'ADV',
#              'start': 438,
#              'tag': 'RB'},
#             {'dep': '',
#              'end': 449,
#              'head': 87,
#              'id': 88,
#              'pos': 'SPACE',
#              'start': 448,
#              'tag': '_SP'},
#             {'dep': 'relcl',
#              'end': 455,
#              'head': 83,
#              'id': 89,
#              'pos': 'VERB',
#              'start': 449,
#              'tag': 'VBD'},
#             {'dep': '',
#              'end': 456,
#              'head': 89,
#              'id': 90,
#              'pos': 'SPACE',
#              'start': 455,
#              'tag': '_SP'},
#             {'dep': 'nsubj',
#              'end': 458,
#              'head': 93,
#              'id': 91,
#              'pos': 'PRON',
#              'start': 456,
#              'tag': 'PRP'},
#             {'dep': 'aux',
#              'end': 464,
#              'head': 93,
#              'id': 92,
#              'pos': 'VERB',
#              'start': 459,
#              'tag': 'MD'},
#             {'dep': 'ccomp',
#              'end': 467,
#              'head': 89,
#              'id': 93,
#              'pos': 'AUX',
#              'start': 465,
#              'tag': 'VB'},
#             {'dep': 'punct',
#              'end': 468,
#              'head': 71,
#              'id': 94,
#              'pos': 'PUNCT',
#              'start': 467,
#              'tag': '.'},
#             {'dep': 'nsubj',
#              'end': 476,
#              'head': 97,
#              'id': 95,
#              'pos': 'NOUN',
#              'start': 469,
#              'tag': 'NNS'},
#             {'dep': 'aux',
#              'end': 481,
#              'head': 97,
#              'id': 96,
#              'pos': 'VERB',
#              'start': 477,
#              'tag': 'MD'},
#             {'dep': 'ROOT',
#              'end': 486,
#              'head': 97,
#              'id': 97,
#              'pos': 'VERB',
#              'start': 482,
#              'tag': 'VB'},
#             {'dep': 'dobj',
#              'end': 491,
#              'head': 97,
#              'id': 98,
#              'pos': 'NOUN',
#              'start': 487,
#              'tag': 'NN'},
#             {'dep': 'prep',
#              'end': 494,
#              'head': 97,
#              'id': 99,
#              'pos': 'ADP',
#              'start': 492,
#              'tag': 'IN'},
#             {'dep': 'det',
#              'end': 498,
#              'head': 103,
#              'id': 100,
#              'pos': 'DET',
#              'start': 495,
#              'tag': 'DT'},
#             {'dep': 'amod',
#              'end': 510,
#              'head': 102,
#              'id': 101,
#              'pos': 'ADJ',
#              'start': 499,
#              'tag': 'JJ'},
#             {'dep': 'compound',
#              'end': 520,
#              'head': 103,
#              'id': 102,
#              'pos': 'NOUN',
#              'start': 511,
#              'tag': 'NN'},
#             {'dep': 'pobj',
#              'end': 527,
#              'head': 99,
#              'id': 103,
#              'pos': 'NOUN',
#              'start': 521,
#              'tag': 'NN'},
#             {'dep': 'compound',
#              'end': 536,
#              'head': 105,
#              'id': 104,
#              'pos': 'PROPN',
#              'start': 528,
#              'tag': 'NNP'},
#             {'dep': 'npadvmod',
#              'end': 542,
#              'head': 97,
#              'id': 105,
#              'pos': 'NOUN',
#              'start': 537,
#              'tag': 'NN'},
#             {'dep': 'punct',
#              'end': 543,
#              'head': 97,
#              'id': 106,
#              'pos': 'PUNCT',
#              'start': 542,
#              'tag': '.'},
#             {'dep': '',
#              'end': 544,
#              'head': 106,
#              'id': 107,
#              'pos': 'SPACE',
#              'start': 543,
#              'tag': '_SP'},
#             {'dep': 'dep',
#              'end': 548,
#              'head': 111,
#              'id': 108,
#              'pos': 'ADJ',
#              'start': 544,
#              'tag': 'JJR'},
#             {'dep': 'punct',
#              'end': 549,
#              'head': 111,
#              'id': 109,
#              'pos': 'PUNCT',
#              'start': 548,
#              'tag': ':'},
#             {'dep': 'nsubj',
#              'end': 555,
#              'head': 111,
#              'id': 110,
#              'pos': 'PROPN',
#              'start': 549,
#              'tag': 'NNP'},
#             {'dep': 'ccomp',
#              'end': 560,
#              'head': 138,
#              'id': 111,
#              'pos': 'VERB',
#              'start': 556,
#              'tag': 'VBZ'},
#             {'dep': 'dobj',
#              'end': 570,
#              'head': 111,
#              'id': 112,
#              'pos': 'PROPN',
#              'start': 561,
#              'tag': 'NNP'},
#             {'dep': 'prep',
#              'end': 573,
#              'head': 111,
#              'id': 113,
#              'pos': 'SCONJ',
#              'start': 571,
#              'tag': 'IN'},
#             {'dep': 'punct',
#              'end': 575,
#              'head': 116,
#              'id': 114,
#              'pos': 'PUNCT',
#              'start': 574,
#              'tag': '``'},
#             {'dep': 'compound',
#              'end': 584,
#              'head': 116,
#              'id': 115,
#              'pos': 'X',
#              'start': 575,
#              'tag': 'FW'},
#             {'dep': 'pobj',
#              'end': 596,
#              'head': 113,
#              'id': 116,
#              'pos': 'NOUN',
#              'start': 585,
#              'tag': 'NN'},
#             {'dep': 'punct',
#              'end': 597,
#              'head': 116,
#              'id': 117,
#              'pos': 'PUNCT',
#              'start': 596,
#              'tag': "''"},
#             {'dep': 'mark',
#              'end': 600,
#              'head': 120,
#              'id': 118,
#              'pos': 'SCONJ',
#              'start': 598,
#              'tag': 'IN'},
#             {'dep': 'nsubj',
#              'end': 605,
#              'head': 120,
#              'id': 119,
#              'pos': 'PROPN',
#              'start': 601,
#              'tag': 'NNPS'},
#             {'dep': 'advcl',
#              'end': 613,
#              'head': 138,
#              'id': 120,
#              'pos': 'VERB',
#              'start': 606,
#              'tag': 'VBP'},
#             {'dep': 'prep',
#              'end': 617,
#              'head': 120,
#              'id': 121,
#              'pos': 'ADP',
#              'start': 614,
#              'tag': 'IN'},
#             {'dep': 'amod',
#              'end': 621,
#              'head': 123,
#              'id': 122,
#              'pos': 'ADJ',
#              'start': 618,
#              'tag': 'JJ'},
#             {'dep': 'pobj',
#              'end': 627,
#              'head': 121,
#              'id': 123,
#              'pos': 'NOUN',
#              'start': 622,
#              'tag': 'NN'},
#             {'dep': 'prep',
#              'end': 630,
#              'head': 123,
#              'id': 124,
#              'pos': 'ADP',
#              'start': 628,
#              'tag': 'IN'},
#             {'dep': 'pobj',
#              'end': 637,
#              'head': 124,
#              'id': 125,
#              'pos': 'NOUN',
#              'start': 631,
#              'tag': 'NN'},
#             {'dep': 'npadvmod',
#              'end': 645,
#              'head': 120,
#              'id': 126,
#              'pos': 'NUM',
#              'start': 638,
#              'tag': 'CD'},
#             {'dep': 'det',
#              'end': 649,
#              'head': 128,
#              'id': 127,
#              'pos': 'DET',
#              'start': 646,
#              'tag': 'DT'},
#             {'dep': 'npadvmod',
#              'end': 654,
#              'head': 120,
#              'id': 128,
#              'pos': 'NOUN',
#              'start': 650,
#              'tag': 'NN'},
#             {'dep': 'punct',
#              'end': 655,
#              'head': 131,
#              'id': 129,
#              'pos': 'PUNCT',
#              'start': 654,
#              'tag': ','},
#             {'dep': 'nsubj',
#              'end': 658,
#              'head': 131,
#              'id': 130,
#              'pos': 'PRON',
#              'start': 656,
#              'tag': 'PRP'},
#             {'dep': 'parataxis',
#              'end': 663,
#              'head': 138,
#              'id': 131,
#              'pos': 'VERB',
#              'start': 659,
#              'tag': 'VBD'},
#             {'dep': 'punct',
#              'end': 664,
#              'head': 131,
#              'id': 132,
#              'pos': 'PUNCT',
#              'start': 663,
#              'tag': ','},
#             {'dep': '',
#              'end': 665,
#              'head': 132,
#              'id': 133,
#              'pos': 'SPACE',
#              'start': 664,
#              'tag': '_SP'},
#             {'dep': 'punct',
#              'end': 666,
#              'head': 138,
#              'id': 134,
#              'pos': 'PUNCT',
#              'start': 665,
#              'tag': '``'},
#             {'dep': 'det',
#              'end': 669,
#              'head': 136,
#              'id': 135,
#              'pos': 'DET',
#              'start': 666,
#              'tag': 'DT'},
#             {'dep': 'nsubj',
#              'end': 676,
#              'head': 138,
#              'id': 136,
#              'pos': 'NOUN',
#              'start': 670,
#              'tag': 'NNS'},
#             {'dep': 'aux',
#              'end': 679,
#              'head': 138,
#              'id': 137,
#              'pos': 'AUX',
#              'start': 677,
#              'tag': 'VBP'},
#             {'dep': 'ROOT',
#              'end': 684,
#              'head': 138,
#              'id': 138,
#              'pos': 'AUX',
#              'start': 680,
#              'tag': 'VB'},
#             {'dep': 'det',
#              'end': 686,
#              'head': 140,
#              'id': 139,
#              'pos': 'DET',
#              'start': 685,
#              'tag': 'DT'},
#             {'dep': 'dobj',
#              'end': 692,
#              'head': 138,
#              'id': 140,
#              'pos': 'NOUN',
#              'start': 687,
#              'tag': 'NN'},
#             {'dep': 'aux',
#              'end': 695,
#              'head': 142,
#              'id': 141,
#              'pos': 'PART',
#              'start': 693,
#              'tag': 'TO'},
#             {'dep': 'acl',
#              'end': 700,
#              'head': 140,
#              'id': 142,
#              'pos': 'VERB',
#              'start': 696,
#              'tag': 'VB'},
#             {'dep': 'prep',
#              'end': 706,
#              'head': 142,
#              'id': 143,
#              'pos': 'ADP',
#              'start': 701,
#              'tag': 'IN'},
#             {'dep': 'det',
#              'end': 710,
#              'head': 145,
#              'id': 144,
#              'pos': 'DET',
#              'start': 707,
#              'tag': 'DT'},
#             {'dep': 'pobj',
#              'end': 717,
#              'head': 143,
#              'id': 145,
#              'pos': 'NOUN',
#              'start': 711,
#              'tag': 'NN'},
#             {'dep': 'prep',
#              'end': 720,
#              'head': 145,
#              'id': 146,
#              'pos': 'ADP',
#              'start': 718,
#              'tag': 'IN'},
#             {'dep': 'det',
#              'end': 722,
#              'head': 148,
#              'id': 147,
#              'pos': 'DET',
#              'start': 721,
#              'tag': 'DT'},
#             {'dep': 'pobj',
#              'end': 730,
#              'head': 146,
#              'id': 148,
#              'pos': 'NOUN',
#              'start': 723,
#              'tag': 'NN'},
#             {'dep': 'punct',
#              'end': 731,
#              'head': 138,
#              'id': 149,
#              'pos': 'PUNCT',
#              'start': 730,
#              'tag': ','},
#             {'dep': 'dobj',
#              'end': 740,
#              'head': 138,
#              'id': 150,
#              'pos': 'PRON',
#              'start': 732,
#              'tag': 'NN'},
#             {'dep': 'nsubj',
#              'end': 744,
#              'head': 153,
#              'id': 151,
#              'pos': 'PRON',
#              'start': 741,
#              'tag': 'WP'},
#             {'dep': 'aux',
#              'end': 746,
#              'head': 153,
#              'id': 152,
#              'pos': 'AUX',
#              'start': 744,
#              'tag': 'VBZ'},
#             {'dep': 'relcl',
#              'end': 754,
#              'head': 150,
#              'id': 153,
#              'pos': 'VERB',
#              'start': 747,
#              'tag': 'VBG'},
#             {'dep': 'prep',
#              'end': 758,
#              'head': 153,
#              'id': 154,
#              'pos': 'ADP',
#              'start': 755,
#              'tag': 'IN'},
#             {'dep': 'pobj',
#              'end': 768,
#              'head': 154,
#              'id': 155,
#              'pos': 'NOUN',
#              'start': 759,
#              'tag': 'NN'},
#             {'dep': 'prep',
#              'end': 771,
#              'head': 155,
#              'id': 156,
#              'pos': 'ADP',
#              'start': 769,
#              'tag': 'IN'},
#             {'dep': 'det',
#              'end': 775,
#              'head': 159,
#              'id': 157,
#              'pos': 'DET',
#              'start': 772,
#              'tag': 'DT'},
#             {'dep': 'compound',
#              'end': 782,
#              'head': 159,
#              'id': 158,
#              'pos': 'PROPN',
#              'start': 776,
#              'tag': 'NNP'},
#             {'dep': 'pobj',
#              'end': 789,
#              'head': 156,
#              'id': 159,
#              'pos': 'PROPN',
#              'start': 783,
#              'tag': 'NNP'},
#             {'dep': 'punct',
#              'end': 792,
#              'head': 155,
#              'id': 160,
#              'pos': 'PUNCT',
#              'start': 790,
#              'tag': ':'},
#             {'dep': 'amod',
#              'end': 797,
#              'head': 162,
#              'id': 161,
#              'pos': 'ADJ',
#              'start': 793,
#              'tag': 'JJ'},
#             {'dep': 'appos',
#              'end': 808,
#              'head': 155,
#              'id': 162,
#              'pos': 'NOUN',
#              'start': 798,
#              'tag': 'NN'},
#             {'dep': 'punct',
#              'end': 809,
#              'head': 138,
#              'id': 163,
#              'pos': 'PUNCT',
#              'start': 808,
#              'tag': '.'},
#             {'dep': 'ROOT',
#              'end': 817,
#              'head': 164,
#              'id': 164,
#              'pos': 'PROPN',
#              'start': 809,
#              'tag': 'NNP'},
#             {'dep': 'punct',
#              'end': 818,
#              'head': 168,
#              'id': 165,
#              'pos': 'PUNCT',
#              'start': 817,
#              'tag': ','},
#             {'dep': 'npadvmod',
#              'end': 826,
#              'head': 168,
#              'id': 166,
#              'pos': 'PROPN',
#              'start': 819,
#              'tag': 'NNP'},
#             {'dep': 'nsubj',
#              'end': 829,
#              'head': 168,
#              'id': 167,
#              'pos': 'PRON',
#              'start': 827,
#              'tag': 'PRP'},
#             {'dep': 'ROOT',
#              'end': 834,
#              'head': 168,
#              'id': 168,
#              'pos': 'VERB',
#              'start': 830,
#              'tag': 'VBD'},
#             {'dep': 'punct',
#              'end': 835,
#              'head': 168,
#              'id': 169,
#              'pos': 'PUNCT',
#              'start': 834,
#              'tag': ':'},
#             {'dep': '',
#              'end': 836,
#              'head': 169,
#              'id': 170,
#              'pos': 'SPACE',
#              'start': 835,
#              'tag': '_SP'},
#             {'dep': 'punct',
#              'end': 837,
#              'head': 168,
#              'id': 171,
#              'pos': 'PUNCT',
#              'start': 836,
#              'tag': '``'},
#             {'dep': 'nsubj',
#              'end': 839,
#              'head': 174,
#              'id': 172,
#              'pos': 'PRON',
#              'start': 837,
#              'tag': 'PRP'},
#             {'dep': 'aux',
#              'end': 844,
#              'head': 174,
#              'id': 173,
#              'pos': 'AUX',
#              'start': 840,
#              'tag': 'VBP'},
#             {'dep': 'ccomp',
#              'end': 853,
#              'head': 168,
#              'id': 174,
#              'pos': 'VERB',
#              'start': 845,
#              'tag': 'VBN'},
#             {'dep': 'advmod',
#              'end': 859,
#              'head': 177,
#              'id': 175,
#              'pos': 'ADV',
#              'start': 854,
#              'tag': 'RB'},
#             {'dep': 'advmod',
#              'end': 862,
#              'head': 177,
#              'id': 176,
#              'pos': 'SCONJ',
#              'start': 860,
#              'tag': 'IN'},
#             {'dep': 'amod',
#              'end': 867,
#              'head': 178,
#              'id': 177,
#              'pos': 'ADJ',
#              'start': 863,
#              'tag': 'JJ'},
#             {'dep': 'dobj',
#              'end': 881,
#              'head': 174,
#              'id': 178,
#              'pos': 'NOUN',
#              'start': 868,
#              'tag': 'NN'},
#             {'dep': 'mark',
#              'end': 884,
#              'head': 183,
#              'id': 179,
#              'pos': 'SCONJ',
#              'start': 882,
#              'tag': 'IN'},
#             {'dep': 'det',
#              'end': 888,
#              'head': 182,
#              'id': 180,
#              'pos': 'DET',
#              'start': 885,
#              'tag': 'DT'},
#             {'dep': 'amod',
#              'end': 894,
#              'head': 182,
#              'id': 181,
#              'pos': 'ADJ',
#              'start': 889,
#              'tag': 'JJ'},
#             {'dep': 'nsubj',
#              'end': 904,
#              'head': 183,
#              'id': 182,
#              'pos': 'NOUN',
#              'start': 895,
#              'tag': 'NN'},
#             {'dep': 'advcl',
#              'end': 908,
#              'head': 174,
#              'id': 183,
#              'pos': 'AUX',
#              'start': 905,
#              'tag': 'VBZ'},
#             {'dep': 'punct',
#              'end': 909,
#              'head': 174,
#              'id': 184,
#              'pos': 'PUNCT',
#              'start': 908,
#              'tag': "''"},
#             {'dep': 'cc',
#              'end': 913,
#              'head': 174,
#              'id': 185,
#              'pos': 'CCONJ',
#              'start': 910,
#              'tag': 'CC'},
#             {'dep': '',
#              'end': 914,
#              'head': 185,
#              'id': 186,
#              'pos': 'SPACE',
#              'start': 913,
#              'tag': '_SP'},
#             {'dep': 'conj',
#              'end': 924,
#              'head': 174,
#              'id': 187,
#              'pos': 'VERB',
#              'start': 914,
#              'tag': 'VBD'},
#             {'dep': 'mark',
#              'end': 929,
#              'head': 195,
#              'id': 188,
#              'pos': 'SCONJ',
#              'start': 925,
#              'tag': 'IN'},
#             {'dep': 'nsubj',
#              'end': 937,
#              'head': 195,
#              'id': 189,
#              'pos': 'NOUN',
#              'start': 930,
#              'tag': 'NNS'},
#             {'dep': 'prep',
#              'end': 942,
#              'head': 189,
#              'id': 190,
#              'pos': 'ADP',
#              'start': 938,
#              'tag': 'IN'},
#             {'dep': 'pobj',
#              'end': 956,
#              'head': 190,
#              'id': 191,
#              'pos': 'NOUN',
#              'start': 943,
#              'tag': 'NNS'},
#             {'dep': 'cc',
#              'end': 960,
#              'head': 191,
#              'id': 192,
#              'pos': 'CCONJ',
#              'start': 957,
#              'tag': 'CC'},
#             {'dep': 'conj',
#              'end': 968,
#              'head': 191,
#              'id': 193,
#              'pos': 'NOUN',
#              'start': 961,
#              'tag': 'NNS'},
#             {'dep': 'aux',
#              'end': 973,
#              'head': 195,
#              'id': 194,
#              'pos': 'AUX',
#              'start': 969,
#              'tag': 'VBP'},
#             {'dep': 'ccomp',
#              'end': 978,
#              'head': 187,
#              'id': 195,
#              'pos': 'VERB',
#              'start': 974,
#              'tag': 'VBN'},
#             {'dep': 'nsubj',
#              'end': 981,
#              'head': 197,
#              'id': 196,
#              'pos': 'PRON',
#              'start': 979,
#              'tag': 'PRP'},
#             {'dep': 'ccomp',
#              'end': 984,
#              'head': 195,
#              'id': 197,
#              'pos': 'AUX',
#              'start': 982,
#              'tag': 'VBZ'},
#             {'dep': 'prep',
#              'end': 987,
#              'head': 197,
#              'id': 198,
#              'pos': 'ADP',
#              'start': 985,
#              'tag': 'IN'},
#             {'dep': 'amod',
#              'end': 992,
#              'head': 200,
#              'id': 199,
#              'pos': 'ADJ',
#              'start': 988,
#              'tag': 'JJ'},
#             {'dep': 'pobj',
#              'end': 999,
#              'head': 198,
#              'id': 200,
#              'pos': 'NOUN',
#              'start': 993,
#              'tag': 'NN'},
#             {'dep': 'punct',
#              'end': 1000,
#              'head': 168,
#              'id': 201,
#              'pos': 'PUNCT',
#              'start': 999,
#              'tag': '.'},
#             {'dep': 'punct',
#              'end': 1002,
#              'head': 203,
#              'id': 202,
#              'pos': 'NOUN',
#              'start': 1000,
#              'tag': 'NNS'},
#             {'dep': 'ccomp',
#              'end': 1008,
#              'head': 223,
#              'id': 203,
#              'pos': 'VERB',
#              'start': 1003,
#              'tag': 'VBP'},
#             {'dep': 'nsubj',
#              'end': 1011,
#              'head': 206,
#              'id': 204,
#              'pos': 'PRON',
#              'start': 1009,
#              'tag': 'PRP'},
#             {'dep': 'aux',
#              'end': 1016,
#              'head': 206,
#              'id': 205,
#              'pos': 'AUX',
#              'start': 1012,
#              'tag': 'VBP'},
#             {'dep': 'ccomp',
#              'end': 1025,
#              'head': 203,
#              'id': 206,
#              'pos': 'VERB',
#              'start': 1017,
#              'tag': 'VBN'},
#             {'dep': 'det',
#              'end': 1027,
#              'head': 210,
#              'id': 207,
#              'pos': 'DET',
#              'start': 1026,
#              'tag': 'DT'},
#             {'dep': 'amod',
#              'end': 1036,
#              'head': 210,
#              'id': 208,
#              'pos': 'ADJ',
#              'start': 1028,
#              'tag': 'JJ'},
#             {'dep': 'amod',
#              'end': 1044,
#              'head': 210,
#              'id': 209,
#              'pos': 'ADJ',
#              'start': 1037,
#              'tag': 'JJ'},
#             {'dep': 'dobj',
#              'end': 1051,
#              'head': 206,
#              'id': 210,
#              'pos': 'NOUN',
#              'start': 1045,
#              'tag': 'NN'},
#             {'dep': 'cc',
#              'end': 1055,
#              'head': 206,
#              'id': 211,
#              'pos': 'CCONJ',
#              'start': 1052,
#              'tag': 'CC'},
#             {'dep': 'nsubj',
#              'end': 1057,
#              'head': 213,
#              'id': 212,
#              'pos': 'PRON',
#              'start': 1056,
#              'tag': 'PRP'},
#             {'dep': 'conj',
#              'end': 1059,
#              'head': 206,
#              'id': 213,
#              'pos': 'VERB',
#              'start': 1057,
#              'tag': 'VBP'},
#             {'dep': 'acomp',
#              'end': 1071,
#              'head': 213,
#              'id': 214,
#              'pos': 'ADJ',
#              'start': 1060,
#              'tag': 'JJ'},
#             {'dep': 'prep',
#              'end': 1074,
#              'head': 214,
#              'id': 215,
#              'pos': 'ADP',
#              'start': 1072,
#              'tag': 'IN'},
#             {'dep': 'dobj',
#              'end': 1079,
#              'head': 219,
#              'id': 216,
#              'pos': 'PRON',
#              'start': 1075,
#              'tag': 'WP'},
#             {'dep': 'nsubj',
#              'end': 1082,
#              'head': 219,
#              'id': 217,
#              'pos': 'PRON',
#              'start': 1080,
#              'tag': 'PRP'},
#             {'dep': 'aux',
#              'end': 1087,
#              'head': 219,
#              'id': 218,
#              'pos': 'AUX',
#              'start': 1083,
#              'tag': 'VBP'},
#             {'dep': 'pcomp',
#              'end': 1092,
#              'head': 215,
#              'id': 219,
#              'pos': 'VERB',
#              'start': 1088,
#              'tag': 'VBN'},
#             {'dep': 'punct',
#              'end': 1093,
#              'head': 223,
#              'id': 220,
#              'pos': 'PUNCT',
#              'start': 1092,
#              'tag': ','},
#             {'dep': 'punct',
#              'end': 1094,
#              'head': 223,
#              'id': 221,
#              'pos': 'PUNCT',
#              'start': 1093,
#              'tag': "''"},
#             {'dep': 'nsubj',
#              'end': 1102,
#              'head': 223,
#              'id': 222,
#              'pos': 'NOUN',
#              'start': 1095,
#              'tag': 'NNS'},
#             {'dep': 'ROOT',
#              'end': 1107,
#              'head': 223,
#              'id': 223,
#              'pos': 'VERB',
#              'start': 1103,
#              'tag': 'VBD'},
#             {'dep': 'punct',
#              'end': 1108,
#              'head': 223,
#              'id': 224,
#              'pos': 'PUNCT',
#              'start': 1107,
#              'tag': '.'},
#             {'dep': 'advmod',
#              'end': 1112,
#              'head': 226,
#              'id': 225,
#              'pos': 'ADV',
#              'start': 1108,
#              'tag': 'WRB'},
#             {'dep': 'advcl',
#              'end': 1118,
#              'head': 246,
#              'id': 226,
#              'pos': 'VERB',
#              'start': 1113,
#              'tag': 'VBN'},
#             {'dep': 'aux',
#              'end': 1121,
#              'head': 228,
#              'id': 227,
#              'pos': 'PART',
#              'start': 1119,
#              'tag': 'TO'},
#             {'dep': 'xcomp',
#              'end': 1129,
#              'head': 226,
#              'id': 228,
#              'pos': 'VERB',
#              'start': 1122,
#              'tag': 'VB'},
#             {'dep': 'mark',
#              'end': 1137,
#              'head': 233,
#              'id': 229,
#              'pos': 'SCONJ',
#              'start': 1130,
#              'tag': 'IN'},
#             {'dep': 'nsubj',
#              'end': 1140,
#              'head': 233,
#              'id': 230,
#              'pos': 'PRON',
#              'start': 1138,
#              'tag': 'PRP'},
#             {'dep': 'aux',
#              'end': 1142,
#              'head': 233,
#              'id': 231,
#              'pos': 'VERB',
#              'start': 1140,
#              'tag': 'MD'},
#             {'dep': 'aux',
#              'end': 1145,
#              'head': 233,
#              'id': 232,
#              'pos': 'AUX',
#              'start': 1143,
#              'tag': 'VB'},
#             {'dep': 'ccomp',
#              'end': 1155,
#              'head': 228,
#              'id': 233,
#              'pos': 'VERB',
#              'start': 1146,
#              'tag': 'VBG'},
#             {'dep': 'amod',
#              'end': 1160,
#              'head': 236,
#              'id': 234,
#              'pos': 'ADJ',
#              'start': 1156,
#              'tag': 'JJ'},
#             {'dep': 'amod',
#              'end': 1168,
#              'head': 236,
#              'id': 235,
#              'pos': 'ADJ',
#              'start': 1161,
#              'tag': 'JJ'},
#             {'dep': 'dobj',
#              'end': 1176,
#              'head': 233,
#              'id': 236,
#              'pos': 'NOUN',
#              'start': 1169,
#              'tag': 'NNS'},
#             {'dep': 'punct',
#              'end': 1177,
#              'head': 239,
#              'id': 237,
#              'pos': 'PUNCT',
#              'start': 1176,
#              'tag': ','},
#             {'dep': 'nsubj',
#              'end': 1185,
#              'head': 239,
#              'id': 238,
#              'pos': 'NOUN',
#              'start': 1178,
#              'tag': 'NNS'},
#             {'dep': 'parataxis',
#              'end': 1195,
#              'head': 246,
#              'id': 239,
#              'pos': 'VERB',
#              'start': 1186,
#              'tag': 'VBD'},
#             {'dep': 'punct',
#              'end': 1196,
#              'head': 239,
#              'id': 240,
#              'pos': 'PUNCT',
#              'start': 1195,
#              'tag': ','},
#             {'dep': '',
#              'end': 1197,
#              'head': 240,
#              'id': 241,
#              'pos': 'SPACE',
#              'start': 1196,
#              'tag': '_SP'},
#             {'dep': 'punct',
#              'end': 1198,
#              'head': 246,
#              'id': 242,
#              'pos': 'PUNCT',
#              'start': 1197,
#              'tag': '``'},
#             {'dep': 'nsubj',
#              'end': 1199,
#              'head': 246,
#              'id': 243,
#              'pos': 'PRON',
#              'start': 1198,
#              'tag': 'PRP'},
#             {'dep': 'aux',
#              'end': 1202,
#              'head': 246,
#              'id': 244,
#              'pos': 'AUX',
#              'start': 1200,
#              'tag': 'VBP'},
#             {'dep': 'neg',
#              'end': 1205,
#              'head': 246,
#              'id': 245,
#              'pos': 'PART',
#              'start': 1202,
#              'tag': 'RB'},
#             {'dep': 'ROOT',
#              'end': 1211,
#              'head': 246,
#              'id': 246,
#              'pos': 'VERB',
#              'start': 1206,
#              'tag': 'VB'},
#             {'dep': 'nsubj',
#              'end': 1214,
#              'head': 248,
#              'id': 247,
#              'pos': 'PRON',
#              'start': 1212,
#              'tag': 'PRP'},
#             {'dep': 'ccomp',
#              'end': 1219,
#              'head': 246,
#              'id': 248,
#              'pos': 'VERB',
#              'start': 1215,
#              'tag': 'MD'},
#             {'dep': 'punct',
#              'end': 1220,
#              'head': 246,
#              'id': 249,
#              'pos': 'PUNCT',
#              'start': 1219,
#              'tag': ','},
#             {'dep': 'intj',
#              'end': 1223,
#              'head': 246,
#              'id': 250,
#              'pos': 'INTJ',
#              'start': 1221,
#              'tag': 'UH'},
#             {'dep': 'punct',
#              'end': 1224,
#              'head': 246,
#              'id': 251,
#              'pos': 'PUNCT',
#              'start': 1223,
#              'tag': '.'},
#             {'dep': 'nsubj',
#              'end': 1232,
#              'head': 254,
#              'id': 252,
#              'pos': 'NOUN',
#              'start': 1224,
#              'tag': 'NNS'},
#             {'dep': 'aux',
#              'end': 1238,
#              'head': 254,
#              'id': 253,
#              'pos': 'VERB',
#              'start': 1233,
#              'tag': 'MD'},
#             {'dep': 'ccomp',
#              'end': 1241,
#              'head': 246,
#              'id': 254,
#              'pos': 'AUX',
#              'start': 1239,
#              'tag': 'VB'},
#             {'dep': 'det',
#              'end': 1245,
#              'head': 257,
#              'id': 255,
#              'pos': 'DET',
#              'start': 1242,
#              'tag': 'DT'},
#             {'dep': 'amod',
#              'end': 1252,
#              'head': 257,
#              'id': 256,
#              'pos': 'ADJ',
#              'start': 1246,
#              'tag': 'JJS'},
#             {'dep': 'attr',
#              'end': 1262,
#              'head': 254,
#              'id': 257,
#              'pos': 'NOUN',
#              'start': 1253,
#              'tag': 'NN'},
#             {'dep': 'prep',
#              'end': 1265,
#              'head': 257,
#              'id': 258,
#              'pos': 'ADP',
#              'start': 1263,
#              'tag': 'IN'},
#             {'dep': 'pobj',
#              'end': 1273,
#              'head': 258,
#              'id': 259,
#              'pos': 'NOUN',
#              'start': 1266,
#              'tag': 'NN'},
#             {'dep': 'mark',
#              'end': 1276,
#              'head': 261,
#              'id': 260,
#              'pos': 'SCONJ',
#              'start': 1274,
#              'tag': 'IN'},
#             {'dep': 'advcl',
#              'end': 1284,
#              'head': 254,
#              'id': 261,
#              'pos': 'VERB',
#              'start': 1277,
#              'tag': 'VBN'},
#             {'dep': 'punct',
#              'end': 1285,
#              'head': 246,
#              'id': 262,
#              'pos': 'PUNCT',
#              'start': 1284,
#              'tag': '.'},
#             {'dep': 'det',
#              'end': 1288,
#              'head': 264,
#              'id': 263,
#              'pos': 'DET',
#              'start': 1285,
#              'tag': 'DT'},
#             {'dep': 'nsubj',
#              'end': 1297,
#              'head': 265,
#              'id': 264,
#              'pos': 'NOUN',
#              'start': 1289,
#              'tag': 'NN'},
#             {'dep': 'ccomp',
#              'end': 1302,
#              'head': 273,
#              'id': 265,
#              'pos': 'VERB',
#              'start': 1298,
#              'tag': 'VBD'},
#             {'dep': 'prep',
#              'end': 1308,
#              'head': 265,
#              'id': 266,
#              'pos': 'ADP',
#              'start': 1303,
#              'tag': 'IN'},
#             {'dep': 'poss',
#              'end': 1312,
#              'head': 270,
#              'id': 267,
#              'pos': 'PROPN',
#              'start': 1309,
#              'tag': 'NNP'},
#             {'dep': 'case',
#              'end': 1314,
#              'head': 267,
#              'id': 268,
#              'pos': 'PART',
#              'start': 1312,
#              'tag': 'POS'},
#             {'dep': 'compound',
#              'end': 1320,
#              'head': 270,
#              'id': 269,
#              'pos': 'PROPN',
#              'start': 1315,
#              'tag': 'NNP'},
#             {'dep': 'compound',
#              'end': 1325,
#              'head': 271,
#              'id': 270,
#              'pos': 'PROPN',
#              'start': 1321,
#              'tag': 'NNP'},
#             {'dep': 'nsubj',
#              'end': 1331,
#              'head': 273,
#              'id': 271,
#              'pos': 'ADV',
#              'start': 1326,
#              'tag': 'RB'},
#             {'dep': '',
#              'end': 1332,
#              'head': 271,
#              'id': 272,
#              'pos': 'SPACE',
#              'start': 1331,
#              'tag': '_SP'},
#             {'dep': 'ROOT',
#              'end': 1337,
#              'head': 273,
#              'id': 273,
#              'pos': 'VERB',
#              'start': 1332,
#              'tag': 'VBD'},
#             {'dep': 'det',
#              'end': 1341,
#              'head': 275,
#              'id': 274,
#              'pos': 'DET',
#              'start': 1338,
#              'tag': 'DT'},
#             {'dep': 'dobj',
#              'end': 1349,
#              'head': 273,
#              'id': 275,
#              'pos': 'PROPN',
#              'start': 1342,
#              'tag': 'NNP'},
#             {'dep': 'prep',
#              'end': 1352,
#              'head': 273,
#              'id': 276,
#              'pos': 'ADP',
#              'start': 1350,
#              'tag': 'IN'},
#             {'dep': 'punct',
#              'end': 1354,
#              'head': 276,
#              'id': 277,
#              'pos': 'PUNCT',
#              'start': 1353,
#              'tag': '``'},
#             {'dep': 'pcomp',
#              'end': 1358,
#              'head': 276,
#              'id': 278,
#              'pos': 'PROPN',
#              'start': 1354,
#              'tag': 'NNP'},
#             {'dep': 'det',
#              'end': 1362,
#              'head': 280,
#              'id': 279,
#              'pos': 'PROPN',
#              'start': 1359,
#              'tag': 'NNP'},
#             {'dep': 'dobj',
#              'end': 1368,
#              'head': 278,
#              'id': 280,
#              'pos': 'PROPN',
#              'start': 1363,
#              'tag': 'NNP'},
#             {'dep': 'punct',
#              'end': 1369,
#              'head': 276,
#              'id': 281,
#              'pos': 'PUNCT',
#              'start': 1368,
#              'tag': "''"},
#             {'dep': 'mark',
#              'end': 1372,
#              'head': 286,
#              'id': 282,
#              'pos': 'SCONJ',
#              'start': 1370,
#              'tag': 'IN'},
#             {'dep': 'nsubj',
#              'end': 1375,
#              'head': 286,
#              'id': 283,
#              'pos': 'PRON',
#              'start': 1373,
#              'tag': 'PRP'},
#             {'dep': 'aux',
#              'end': 1377,
#              'head': 286,
#              'id': 284,
#              'pos': 'VERB',
#              'start': 1375,
#              'tag': 'MD'},
#             {'dep': 'aux',
#              'end': 1380,
#              'head': 286,
#              'id': 285,
#              'pos': 'AUX',
#              'start': 1378,
#              'tag': 'VB'},
#             {'dep': 'advcl',
#              'end': 1390,
#              'head': 273,
#              'id': 286,
#              'pos': 'VERB',
#              'start': 1381,
#              'tag': 'VBG'},
#             {'dep': 'det',
#              'end': 1394,
#              'head': 289,
#              'id': 287,
#              'pos': 'DET',
#              'start': 1391,
#              'tag': 'DT'},
#             {'dep': 'amod',
#              'end': 1399,
#              'head': 289,
#              'id': 288,
#              'pos': 'ADJ',
#              'start': 1395,
#              'tag': 'JJR'},
#             {'dep': 'dobj',
#              'end': 1411,
#              'head': 286,
#              'id': 289,
#              'pos': 'NOUN',
#              'start': 1400,
#              'tag': 'NN'},
#             {'dep': 'punct',
#              'end': 1412,
#              'head': 286,
#              'id': 290,
#              'pos': 'PUNCT',
#              'start': 1411,
#              'tag': ','},
#             {'dep': 'prep',
#              'end': 1417,
#              'head': 286,
#              'id': 291,
#              'pos': 'ADP',
#              'start': 1413,
#              'tag': 'IN'},
#             {'dep': 'det',
#              'end': 1421,
#              'head': 293,
#              'id': 292,
#              'pos': 'DET',
#              'start': 1418,
#              'tag': 'DT'},
#             {'dep': 'nsubj',
#              'end': 1426,
#              'head': 294,
#              'id': 293,
#              'pos': 'NOUN',
#              'start': 1422,
#              'tag': 'NN'},
#             {'dep': 'pcomp',
#              'end': 1434,
#              'head': 291,
#              'id': 294,
#              'pos': 'VERB',
#              'start': 1427,
#              'tag': 'VBG'},
#             {'dep': 'mark',
#              'end': 1439,
#              'head': 301,
#              'id': 295,
#              'pos': 'SCONJ',
#              'start': 1435,
#              'tag': 'IN'},
#             {'dep': 'punct',
#              'end': 1440,
#              'head': 301,
#              'id': 296,
#              'pos': 'PUNCT',
#              'start': 1439,
#              'tag': ','},
#             {'dep': 'punct',
#              'end': 1442,
#              'head': 301,
#              'id': 297,
#              'pos': 'PUNCT',
#              'start': 1441,
#              'tag': '``'},
#             {'dep': 'det',
#              'end': 1444,
#              'head': 300,
#              'id': 298,
#              'pos': 'DET',
#              'start': 1442,
#              'tag': 'DT'},
#             {'dep': 'amod',
#              'end': 1450,
#              'head': 300,
#              'id': 299,
#              'pos': 'ADJ',
#              'start': 1445,
#              'tag': 'JJ'},
#             {'dep': 'nsubj',
#              'end': 1461,
#              'head': 301,
#              'id': 300,
#              'pos': 'NOUN',
#              'start': 1451,
#              'tag': 'NNS'},
#             {'dep': 'ccomp',
#              'end': 1465,
#              'head': 294,
#              'id': 301,
#              'pos': 'AUX',
#              'start': 1462,
#              'tag': 'VBD'},
#             {'dep': 'det',
#              'end': 1467,
#              'head': 304,
#              'id': 302,
#              'pos': 'DET',
#              'start': 1466,
#              'tag': 'DT'},
#             {'dep': 'compound',
#              'end': 1473,
#              'head': 304,
#              'id': 303,
#              'pos': 'NOUN',
#              'start': 1468,
#              'tag': 'NN'},
#             {'dep': 'dobj',
#              'end': 1480,
#              'head': 301,
#              'id': 304,
#              'pos': 'NOUN',
#              'start': 1474,
#              'tag': 'NN'},
#             {'dep': 'punct',
#              'end': 1481,
#              'head': 273,
#              'id': 305,
#              'pos': 'PUNCT',
#              'start': 1480,
#              'tag': '.'},
#             {'dep': 'punct',
#              'end': 1482,
#              'head': 273,
#              'id': 306,
#              'pos': 'PUNCT',
#              'start': 1481,
#              'tag': "''"},
#             {'dep': '',
#              'end': 1483,
#              'head': 306,
#              'id': 307,
#              'pos': 'SPACE',
#              'start': 1482,
#              'tag': '_SP'}]}

# %% [markdown]
# ## Sentiment Analysis

# %%
from nltk.corpus import stopwords

# import SentimentIntensityAnalyzer class 
# from vaderSentiment.vaderSentiment module. 
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Create a SentimentIntensityAnalyzer object. 
sid_obj = SentimentIntensityAnalyzer()



cursor = db_news_content.find({}, {'_id':1, 'word_list' : 1 })
article = list(cursor)[0]
word_list = article['word_list']

filtered_words = [word for word in word_list if word not in stopwords.words('english')]

filtered_sentence = f' '.join(filtered_words)


sentiment_dict = sid_obj.polarity_scores(filtered_sentence)
sentiment_dict
# Out:
# {'neg': 0.061, 'neu': 0.881, 'pos': 0.058, 'compound': -0.1027}

# %%
cursor = db_news_content.find({}, {'_id':1, 'word_list' : 1 })
bag_of_words = []
for article in list(cursor) :
    bag_of_words.extend(article['word_list'])
    
len(bag_of_words)
# Out:
# 1462551

# %%
vectorizer = CountVectorizer(stop_words='english')
doc_word = vectorizer.fit_transform(bag_of_words)
doc_word.shape
# Out:
# (1462551, 30456)

# %% [markdown]
# ## Topic Modeling below

# %%
lsa = TruncatedSVD(10)
doc_topic = lsa.fit_transform(doc_word)
lsa.explained_variance_ratio_
# Out:
# array([0.01052819, 0.00981248, 0.00868021, 0.00862759, 0.00844439,
#        0.00776041, 0.00769827, 0.0070162 , 0.00657115, 0.00628442])

# %%
def display_topics(model, feature_names, no_top_words, topic_names=None):
    for ix, topic in enumerate(model.components_):
        if not topic_names or not topic_names[ix]:
            print("\nTopic ", ix)
        else:
            print("\nTopic: '",topic_names[ix],"'")
        print(", ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

# %%
display_topics(lsa, vectorizer.get_feature_names(), 5)
# Out:
# Topic  0
# said, party, voters, klobuchar, primary
#
# Topic  1
# sanders, party, bloomberg, bernie, klobuchar
#
# Topic  2
# iowa, support, voters, candidates, people
#
# Topic  3
# campaign, iowa, support, candidates, mayor
#
# Topic  4
# biden, support, voters, candidates, iowa
#
# Topic  5
# democratic, support, voters, party, bernie
#
# Topic  6
# new, party, klobuchar, primary, hampshire
#
# Topic  7
# warren, hampshire, presidential, candidate, caucus
#
# Topic  8
# bloomberg, bernie, hampshire, party, mayor
#
# Topic  9
# trump, presidential, hampshire, tuesday, president

# %%
import spacy

cursor = db_news_content.find({}, {'_id':1, 'text' : 1 })

article = list(cursor)[1]

nlp = spacy.load("en_core_web_sm")
doc = nlp(article['text'])

# document level
ents = [(e.text, e.label_, e.kb_id_) for e in doc.ents]
print(ents)  # [('Ada Lovelace', 'PERSON', 'Q7259'), ('London', 'GPE', 'Q84')]

# token level
ent_ada_0 = [doc[0].text, doc[0].ent_type_, doc[0].ent_kb_id_]
ent_ada_1 = [doc[1].text, doc[1].ent_type_, doc[1].ent_kb_id_]
ent_london_5 = [doc[2].text, doc[2].ent_type_, doc[2].ent_kb_id_]
print(ent_ada_0)  # ['Ada', 'PERSON', 'Q7259']
print(ent_ada_1)  # ['Lovelace', 'PERSON', 'Q7259']
print(ent_london_5)  # ['London', 'GPE', 'Q84']
# Out:
# [('Bernie Sanders', 'PERSON', ''), ('D-VT', 'ORG', ''), ('2020', 'CARDINAL', ''), ('Democratic', 'NORP', ''), ('last year', 'DATE', ''), ('2020', 'DATE', ''), ('CNN', 'ORG', ''), ('Town Hall', 'FAC', ''), ('three', 'CARDINAL', ''), ('three', 'CARDINAL', ''), ('four', 'CARDINAL', ''), ('October 2019', 'DATE', ''), ('Las Vegas', 'GPE', ''), ('two days', 'DATE', ''), ('about two weeks', 'DATE', '')]
# ['Press', '', '']
# ['Play', '', '']
# [',', '', '']
